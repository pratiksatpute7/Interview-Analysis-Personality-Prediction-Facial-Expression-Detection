# %%
import wx
import cv2
import time
import os
from PIL import Image, ImageTk
import PIL.Image
import base64
import pymongo
from tkinter import *
from tkinter import messagebox
import time
import threading
from textblob import TextBlob
import nltk
import inspect
from personality import personality
import pickle
from tkinter import *
from tkinter import messagebox
from keras.preprocessing.image import img_to_array
import imutils
from keras.models import load_model
import numpy as np
from interview import interview 
from sys import exit

from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
    
app= wx.App() 
width, height = wx.GetDisplaySize()
#resolution=str(w)+'x'+str(h)
#app.geometry(resolution)
window= wx.Frame(None, title = "Registration", size = (width,height)) 
panel= wx.Panel(window) 
client = pymongo.MongoClient("mongodb+srv://Vaibhav:test@cluster0-4wlro.mongodb.net/test?retryWrites=true&w=majority")
db = client.OCEAN
col = db.user
b64string=''
#font = wx.Font(10, wx.ROMAN, wx.NORMAL, wx.NORMAL)
box1= wx.StaticBox(panel, wx.ID_ANY, "Applicant Information", size =((width/ 1.05,(height/ 5)+ 150)), pos= (20, 10))
label= wx.StaticText(box1, label = "* Full Name", pos= (40, 30))
box3= wx.StaticBox(box1 , label = "", size= (205, 250), pos= (1150, 25))
#box4= wx.StaticBox(box3 , label = "", size= (180, 180), pos= (12, 10 ))
img= wx.Panel(box3, -1, size= (180, 180), pos= (2, 2))
#img.Centre()
ct= ""
score= 0.0
o_score= 0.0
c_score= 0.0
e_score= 0.0
a_score= 0.0
n_score= 0.0
sent= ""
scores= [[]]
def capture(self):
	# Creating a video object
	video = cv2.VideoCapture(0) 
	a = 0
	while True:
		a = a + 1
		# Create a frame object
		check, frame = video.read()
		cv2.imshow("Capturing",frame)
		key = cv2.waitKey(1)
		if key == ord('q'):
			break
	# 7. image saving
	pic= cv2.imwrite("image.jpg",frame)
	video.release()
	cv2.destroyAllWindows	
	
	imgg= PIL.Image.open("C:\\Users\\91996\\BE\\GUI\\gui\\image.jpg")
	
	area= (80, 60, 560, 420)
	imgg = imgg.crop(area)
	imgg.save("image.jpg")
	with open("image.jpg", "rb") as image:
		b64string = base64.b64encode(image.read())

	jpg = wx.Image(('C:\\Users\\91996\\BE\\GUI\\gui\\image.jpg'), wx.BITMAP_TYPE_JPEG).Rescale(170, 150).ConvertToBitmap()
	#pos= 10
	wx.StaticBitmap(img, -1, jpg, (30, 30))
	#wx.Image(img, size=(180, 180), data= pic) 
cap= wx.Button(box3, label= "Capture", size= (60, 25), pos= (70, 200))
cap.Bind(wx.EVT_BUTTON, capture)
name= wx.TextCtrl(box1,size = (850, 25), pos= (150, 25))  
label= wx.StaticText(box1, label = "* Age", pos= (40, 100))
age= wx.TextCtrl(box1,size = (250, 25), pos= (150, 95))
label= wx.StaticText(box1, label= "* Gender", pos= (450,95))
box4= wx.StaticBox(box1 , label = "", size= (450, 45), pos= (550,80))
m= wx.RadioButton(box4, label= "Male", pos= (50,20), style= 0)
f= wx.RadioButton(box4, label= "Female", pos= (200, 20), style= 0)
ot= wx.RadioButton(box4, label= "Others", pos= (350,20), style= 0)
#label.SetFont(font) 
label= wx.StaticText(box1, label = "* Contact", pos= (40, 170))
contact= wx.TextCtrl(box1,size = (250, 25), pos= (150, 170))
label= wx.StaticText(box1, label = "* Email", pos= (450, 170))
#label.SetFont(font)
email= wx.TextCtrl(box1,size = (450, 25), pos= (550, 170)) 
label= wx.StaticText(box1, label = "* Nationality", pos= (40, 250))
label= wx.StaticText(box1, label = "* - required fields", pos= (1300, 290))
font1 = wx.Font(9, wx.ROMAN, wx.ITALIC, wx.NORMAL)
label.SetFont(font1)

#label.SetFont(font)
other= wx.TextCtrl(box1, size= (550, 25), pos= (450, 245))
other.SetHint("Enter here")
other.Enable(False)
def onClick1(self):
	if ind.GetValue()== True:
		other.Enable(False)
def onClick2(self):
	if othr.GetValue()== True:
		other.Enable(True)	
ind= wx.RadioButton(box1, label= "Indian", pos= (150, 250), style= 0)
ind.Bind(wx.EVT_RADIOBUTTON, onClick1)
othr= wx.RadioButton(box1, label= "Other", pos= (350, 250), style= 0)
othr.Bind(wx.EVT_RADIOBUTTON, onClick2)

box2= wx.StaticBox(panel, wx.ID_ANY, "Education Details", size =((width/ 1.05,(height/ 1.25)-370)), pos= (20, height/ 5 + 200))
label= wx.StaticText(box2, label = "QUALIFICATION", pos= (150, 40))
label= wx.StaticText(box2, label = "INSTITUTION/ SCHOOL", pos= (450, 40))
label= wx.StaticText(box2, label = "BOARD/ UNIVERSITY", pos= (750, 40))
label= wx.StaticText(box2, label = "PERCENTAGE/ CGPA", pos= (1050, 40))
qua1= wx.TextCtrl(box2, size= (200, 25), pos= (90, 90))
qua1.SetHint("Graduation")
qua2= wx.TextCtrl(box2, size= (200, 25), pos= (90, 140))
qua2.SetHint("HSC/ XII/ Diploma")
qua3= wx.TextCtrl(box2, size= (200, 25), pos= (90, 190))
qua3.SetHint("SSC/ X")
inst1= wx.TextCtrl(box2, size= (200, 25), pos= (410, 90))
inst2= wx.TextCtrl(box2, size= (200, 25), pos= (410, 140))
inst3= wx.TextCtrl(box2, size= (200, 25), pos= (410, 190))
brd1= wx.TextCtrl(box2, size= (200, 25), pos= (700, 90))
brd2= wx.TextCtrl(box2, size= (200, 25), pos= (700, 140))
brd3= wx.TextCtrl(box2, size= (200, 25), pos= (700, 190))
gp1= wx.TextCtrl(box2, size= (200, 25), pos= (1000, 90))
gp2= wx.TextCtrl(box2, size= (200, 25), pos= (1000, 140))
gp3= wx.TextCtrl(box2, size= (200, 25), pos= (1000, 190))
label= wx.StaticText(box2, label = "Certificates/ Skills", pos= (40, 260))
cs= wx.TextCtrl(box2, size= (1250, 25), pos =(150, 255))

def onsub(self):
	l=[1,2,3,4,5,6,7,8,9,0]
	nam= str(name.GetValue())
	ag= str(age.GetValue())
	gender= ""
	global ct
	ct= str(contact.GetValue())
	em= str(email.GetValue())
	qua11= str(qua1.GetValue())	
	qua22= str(qua2.GetValue())
	qua33= str(qua3.GetValue())
	inst11= str(inst1.GetValue())	
	inst22= str(inst2.GetValue())
	inst33= str(inst3.GetValue())
	brd11= str(brd1.GetValue())	
	brd22= str(brd2.GetValue())
	brd33= str(brd3.GetValue())	
	gp11= str(gp1.GetValue())
	gp22= str(gp2.GetValue())
	gp33= str(gp3.GetValue())
	cs1= str(cs.GetValue())
	if m.GetValue()== 1:
		gender= m.GetLabel()
	elif f.GetValue()== 1:
		gender= f.GetLabel()
	elif ot.GetValue()== 1:
		gender= ot.GetLabel()
	if ind.GetValue()== True:
		nat= ind.GetLabel()
		#print(nat)
	elif othr.GetValue()== True:
		nat= str(other.GetValue())
	
	#validation
	if nam== "" or ag== "" or gender== "" or ct== "" or em== "":
		wx.MessageBox("Required Fields cannot be blank.")
		
	if len(ct)!= 10:
		wx.MessageBox("Please enter a valid contact number.")

	else:
		for i in ct:
			if int(i) not in l:					
				wx.MessageBox("Please enter a valid contact number.")
					
	import re   
	regex = '^\w+([\.-]?\w+)*@\w+([\.-]?\w+)*(\.\w{2,3})+$' 
	if not(re.search(regex,em)):  	
		wx.MessageBox("Please enter a valid email id.")
			
	if ag.isnumeric()== 0:		
		wx.MessageBox("Age must be a valid number only.")
	if gender== "Male":
		gen= 0
	if gender== "Female":
		gen= 1
	else:
		gen= -1
	scores[0].append(gen)	
	scores[0].append(int(ag))
	#print(scores)
	
	data= {
		"Name": nam,
		"Age": ag,
		"Gender": gender,
		"Contact Number": ct,
		"Email-ID": em,
		"Nationality": nat,
		"Grad": qua11,
		"Institution or School": inst11,
		"Board or University": brd11,
		"Percentage or CGPA": gp11,
		"HSC or XII or Diploma": qua22,
		"Institution or School": inst22,
		"Board or University": brd22,
		"Percentage or CGPA": gp22,
		"SSC or X": qua33,
		"Institution or School": inst33,
		"Board or University": brd33,
		"Percentage or CGPA": gp33,
		"Certificates or Skills": cs1,
		"Image": b64string,
		
		"Aptitude score": 0,
		"Openness": 0,
		"Conscientiousness": 0,
		"Extraversion": 0,
		"Agreeableness": 0,
		"Neuroticism": 0,
		"Sentiment": "",
		"Expression" : "",
		"Personality" : ""}
	col.insert_one(data)
	wx.MessageBox('Registration Successful.\nNote:\nYour Registered Contact Number is your password. ')
	window2= wx.Frame(window, title = "Login", size = (500, 530), pos= (width/4,height/4)) 
	panel= wx.Panel(window2) 
	box1= wx.StaticBox(panel, wx.ID_ANY, "", size =(450, 450), pos= (15, 15))
	label= wx.StaticText(box1, label="Login", pos= (190, 50))
	box= wx.StaticBox(box1, wx.ID_ANY, "Email-ID", size =(400, 80), pos= (25, 150))
	email1= wx.TextCtrl(box1, size= (365, 25), pos= (40, 180))
	box= wx.StaticBox(box1, wx.ID_ANY, "Password", size =(400, 80), pos= (25, 250))
	pd= wx.TextCtrl(box1, size= (365, 25), pos= (40, 280), style= wx.TE_PASSWORD)
	
	def onlogin(self):
			eid= str(email1.GetValue())
			pwd= str(pd.GetValue())
			dis= col.find_one({"Email-ID": eid}, {"id": 0})
			pwd2= dis["Contact Number"]
			if pwd== pwd2:
				wx.MessageBox('Login Successful.\nAre you ready for the upcoming stages?\nAll the best !', 'Info', wx.YES_NO  )
				window3= wx.Frame(window2, title = "Aptitude Details", size = (width,height)) 
				panel= wx.Panel(window3) 
				box1= wx.StaticBox(panel, size =(width-50, height/ 2- 100), pos=(15, 10))
				box2= wx.StaticBox(panel, size =(width-50, height/ 2- 50), pos=(15, height/2- 50))
				label= wx.StaticText(box1, label= "Aptitude Test Rules:\n\n\n→\tThe test consist of three sections i.e Quantitative Reasoning, Verbal Reasoning, and Logical Reasoning.\n\n\n→\tEach section consists of five questions.\n\n\n→\tAll questions are multiple choice and there is only one correct answer.\n\n\n→\tNote each question carry +1 mark for a correct answer and -1/4 for a wrong answer.\n\n\n→\tNo marks will be deducted for unattempted question.\n\n\n→\tThe candidate will be given 30 minutes to attempt the test. He or she may submit the test before time by clicking on 'End Quiz'.  ",size =(width-150, height/ 2- 130), pos=(20, 20))
				label= wx.StaticText(box2, label= "Psychometric Test Rules :\n\n\n→\tThe test consist of five sections i.e Openness, Conscientiousness, Extraversion, Agreeableness and Neuroticism.\n\n\n→\tEach section consists of eight questions.\n\n\n→\tAll questions are multiple choice. Note each alternative carries an individual score and the total score in each section will be calculated based on the candidate's answers.\n\n\n→\tThe candidate will be given 40 minutes to attempt the test. He or she may submit the test before time by clicking on 'End Quiz'.",size =(width-150, height/ 2- 200), pos= (20, 20))
				chck= wx.CheckBox(box2, label= "", pos= (50, height/2- 170))
				label=wx.StaticText(box2, label= "By clicking you agree to bound by the rules of the test. In case of any violations serious action will be taken which can also lead to rejection of your candidature .", pos= (70, height/2- 170))
				def f(self):
					if chck.GetValue()==0:
						wx.MessageBox("Please accept the terms to proceed to further stages.")
					else:
						window3.Show(False)
						window4 = Tk()
						window4.title("Aptitude Test")
						w=window4.winfo_screenwidth()
						h=window4.winfo_screenheight()
						resolution=str(w)+'x'+str(h)
						window4.geometry(resolution)
						#window.resizable(False,False)
						window4.configure()
						def time_lft():
							#print("Started")
							while True:
								secd= 1800
								while secd> 0:
									m, s= divmod(secd, 60)
									h, m= divmod(m, 60)
									time_left= str(h).zfill(2)+" : "+ str(m).zfill(2)+" : "+ str(s).zfill(2)
									#print(time_left+ "\r", end="")
									tm.delete(0,END)
									tm.insert(0,str(time_left))
									#tm.configure(state= disabled)
									time.sleep(1)
									#tim.WriteText("\t\t\t\t\t\t")
									secd-= 1
									if secd== 10:
										messagebox.showinfo("Last "+ str(secd)+" seconds left!")
									if secd== 0:
										messagebox.showinfo("Time Over!")
										window4.Close()
						f1= Frame(window4)
						f1.configure(bg="#d9d9d9", height= 100, width= w- 40, bd= 10)
						f2= Frame(window4)
						f2.configure(bg="#d9d9d9", height= h-200, width= 300, bd= 10)
						f3= Frame(window4)
						f3.configure(bg="#d9d9d9", height= h-200, width= w- 350, bd= 10)
						f1.place(x= 10, y= 10)
						f2.place(x= 10, y= 120)
						f3.place(x= 320, y= 120)
						temp1= temp2= temp3= count= 0
						question_lbl= StringVar()
						c1= StringVar()
						c2= StringVar()
						c3= StringVar()
						c4= StringVar()
						opt= StringVar()
						question= Label(f3, textvariable= question_lbl, justify= LEFT)
						#question.place(x= 100, y= 50 )
						#score= 0.0
						ans_key={111: 2, 122: 2, 133: 1, 144: 1, 155: 1, 211: 2, 222: 3, 233: 1, 244: 4, 255: 4, 311: 2, 322: 2,
								 333: 1, 344: 2, 355: 2}

						ans=[]
						def quest():
							var= op.get()
							temp= var
							if var!= 0:	
								def mcq():
									var2= q.get()
									temp2= var2
									#print(var, var2)
									if temp== 1:
										if temp2== 11:
											question_lbl.set("Ques.\tA trader mixes 26 kg of rice at Rs. 20 per kg with 30 kg of rice of other variety at Rs. 36 per kg and sells the mixture at Rs. 30 per kg.\n\tHis profit percent is:")
											ans = ["A. No profit, no loss", "B. 5%", "C. 8%", "D. 10%"]
											count= 111
																
										elif temp2== 22:
											question_lbl.set("Ques.\tA can do a piece of work in 10 days, B in 15 days. They work together for 5 days, the rest of the work is finished by C in two more days.\n\tIf they get Rs. 3000 as wages for the whole work,\n\twhat are the daily wages of A, B and C respectively (in Rs):")
											ans = ["A. 200, 250, 300", "A. 300, 200, 250", "C. 200, 300, 400", "D. None of these"]
											count= 122
											
										elif temp2== 33:
											question_lbl.set("Ques.\tA thief is noticed by a policeman from a distance of 200 m. The thief starts running and the policeman chases him.\n\tThe thief and the policeman run at the rate of 10 km and 11 km per hour respectively.\n\tWhat is the distance between them after 6 minutes?")
											ans = ["A. 100m", "A. 150m", "C. 190m", "D. 200m"]
											count= 133
											
										elif temp2== 44:
											question_lbl.set("Ques.\tA grocer has a sale of Rs 6435, Rs. 6927, Rs. 6855, Rs. 7230 and Rs. 6562 for 5 consecutive months.\n\tHow much sale must he have in the sixth month so that he gets an average sale of Rs, 6500 ?")
											ans = ["A. 4991", "A. 5467", "C. 5987", "D. 6453"]
											count= 144
											
										elif temp2== 55:
											question_lbl.set("Ques.\tThe sum of all two digit numbers divisible by 5 is:")
											ans = ["A. 945", "A. 678", "C. 439", "D. 950"]
											count= 155
											
									elif temp== 2:
										if temp2== 11:
											question_lbl.set("Ques.\tDespite his best efforts to conceal his anger ......")
											ans = ["A. we could detect that he was very happy","B. people came to know that he was annoyed", "C. he succeeded in camouflaging his emotions","D. he could succeed in doing it easily"]
											count= 211
											
										elif temp2== 22:
											question_lbl.set("Ques. Even if it rains I shall come means ......")
											ans = ["A. if I come it will not rain", "B. if it rains I shall not come", "C. I will certainly come whether it rains or not", "D. whenever there is rain I shall come"]
											count= 222
											
										elif temp2== 33:
											question_lbl.set("Ques. His appearance is unsmiling but ..... ")
											ans = ["A.	but tense as compared to earlier", "B.	and tense as compared to earlier", "C.	as there was already no tension at all", "D.	and tension-free as compared to earlier"]
											count= 233
											
										elif temp2== 44:
											question_lbl.set("Ques. Although initial investigations pointed towards him ......")
											ans = ["A.	the preceding events corroborated his involvement in the crime", "B.	the additional information confirmed his guilt", "C.	the subsequent events established that he was guilt", "D.	the subsequent events proved that he was innocent"]
											count= 244
											
										elif temp2== 55:
											question_lbl.set("Ques. Obnoxious is similar in meaning to .....")
											ans = ["A. Pleasant", "B. Plenty", "C. Distasteful", "D. Nausicious"]
											count= 255
											
									elif temp== 3:
										if temp2== 11:
											question_lbl.set("Ques. Look at this series: 2, 1, (1/2), (1/4), ... What number should come next?")
											ans = ["A.	(1/3)", "B.	(1/8)", "C. C.	(1/4)", "D.	(1/16)"]
											count= 311
											
										elif temp2== 22:
											question_lbl.set("Ques. Tanya is older than Eric.\n\tCliff is older than Tanya.\n\tEric is older than Cliff.\n\tIf the first two statements are true, the third statement is :")
											ans = ["A.	true", "B.	false", "C.	uncertain", "D. Data insufficient"]
											count= 322
											
										elif temp2== 33:
											question_lbl.set("Ques. All the trees in the park are flowering trees.\n\tSome of the trees in the park are dogwoods.\n\tAll dogwoods in the park are flowering trees.\n\tIf the first two statements are true, the third statement is")
											ans = ["A.	true", "B.	false", "C.	uncertain", "D. Data insufficient"]
											count= 333
											
										elif temp2== 44:
											question_lbl.set("Ques. Cup is to coffee as bowl is to .....")
											ans = ["A. dish", "B. Soup", "C. Spoon", "D. Food"]
											count= 344
											
										elif temp2== 55:
											question_lbl.set("Ques. Look at this series: 53, 53, 40, 40, 27, 27, ... What number should come next?")
											ans = ["A. 12", "B. 14", "C. 27", "D. 53"]
											count= 355
											
									c1.set(ans[0])
									c2.set(ans[1])
									c3.set(ans[2])
									c4.set(ans[3])		
									
									def answ():
										global score
										var3= c.get()
										#print(var, temp2, var3)
										key= var*100+temp2
										if var3== ans_key.get(key):
											score= score+ 1.0
										else:
											score= score- 0.25
								
									c= IntVar()
									ch1= Radiobutton(f3, textvariable= c1, variable= c, value= 1)
									ch2= Radiobutton(f3, textvariable= c2, variable= c, value= 2)
									ch3= Radiobutton(f3, textvariable= c3, variable= c, value= 3)
									ch4= Radiobutton(f3, textvariable= c4, variable= c, value= 4)
									question.place(x= 100, y= 50 )
									ch1.place(x= 100, y= 250 )
									ch2.place(x= 600, y= 250 )
									ch3.place(x= 100, y= 350 )
									ch4.place(x= 600, y= 350 )	
									subb2= Button(f3, text= "Submit", command= answ)
									subb2.place(x= 200,y= 500)
									def re():
										global score
										messagebox.showwarning(None,"Are you sure you want to end the quiz ?")
										#messagebox.showinfo("Result", "Score= "+ str(score))
										#global scores
										#scores.append(score)
										#print(score)
										window4.destroy()
										window5 = Tk()
										window5.title("Psychometric Test")
										w=window5.winfo_screenwidth()
										h=window5.winfo_screenheight()
										resolution=str(w)+'x'+str(h)
										window5.geometry(resolution)
										window5.resizable(False,False)
										window5.configure()
										def time_lft():
											while True:
												secd= 2400
												while secd> 0:
													m, s= divmod(secd, 60)
													h, m= divmod(m, 60)
													time_left= str(h).zfill(2)+" : "+ str(m).zfill(2)+" : "+ str(s).zfill(2)
													tm2.delete(0,END)
													tm2.insert(0,str(time_left))
													time.sleep(1)
													secd-= 1
													if secd== 10:
														messagebox.showinfo("Last "+ str(secd)+" seconds left!")
													if secd== 0:
														messagebox.showinfo("Time Over!")
														window5.Close()
										f1= Frame(window5)
										f1.configure(bg="#d9d9d9", height= 100, width= w- 40, bd= 10)
										f2= Frame(window5)
										f2.configure(bg="#d9d9d9", height= h-200, width= 300, bd= 10)
										f3= Frame(window5)
										f3.configure(bg="#d9d9d9", height= h-200, width= w- 350, bd= 10)
										f1.place(x= 10, y= 10)
										f2.place(x= 10, y= 120)
										f3.place(x= 320, y= 120)
										temp1= temp2= temp3= count= 0
										question_lbl= StringVar()
										c1= StringVar()
										c2= StringVar()
										c3= StringVar()
										c4= StringVar()
										opt= StringVar()
										question= Label(f3, textvariable= question_lbl, justify= LEFT)
										question.place(x= 100, y= 50 )
										o_score= 0.0
										c_score= 0.0
										e_score= 0.0
										a_score= 0.0
										n_score= 0.0

										ans= []
										def quest():
											var= opn.get()
											temp= var
											if temp!= 0:	
												def mcq():
													var2= qs.get()
													temp2= var2
													#print(var, var2)
													if temp== 1:
														if temp2== 11:
															question_lbl.set("Ques. Do you like to attend festivals ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 111
																				
														elif temp2== 22:
															question_lbl.set("Ques. Do you like philosophical discussions ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 122
															
														elif temp2== 33:
															question_lbl.set("Ques. Do you have stage fear ?")
															ans = ["A.  No", "A.  Not Really", "C.  Yes", "D.  Very Much"]
															count= 133
															
														elif temp2== 44:
															question_lbl.set("Ques. Do you prefer to stick with things you know ?")
															ans = ["A.  No", "A.  Not Really", "C.  Yes", "D.  Very Much"]
															count= 144
															
														elif temp2== 55:
															question_lbl.set("Ques. Do you believe there is no absolute right and wrong ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 155
															
														elif temp2== 66:
															question_lbl.set("Ques. Do you experience your emotions immensely ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 166
															
														elif temp2== 77:
															question_lbl.set("Ques. Do you like keeping the conversations short ?")
															ans = ["A.  No", "A.  Not Really", "C.  Yes", "D.  Very Much"]
															count= 177
															
														elif temp2== 88:
															question_lbl.set("Ques. Do you have difficulty understanding abstract ideas ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 188
															
													elif temp== 2:
														if temp2== 11:
															question_lbl.set("Ques. Do you complete tasks successfully everytime ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 211
															
														elif temp2== 22:
															question_lbl.set("Ques. Do you leave a mess in your room ?")
															ans = ["A.  No", "B.  Sometimes", "C.  Most of the time", "D.  Yes"]
															count= 222
															
														elif temp2== 33:
															question_lbl.set("Ques. Do you do more than whats expected from you ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 233
															
														elif temp2== 44:
															question_lbl.set("Ques. Do you handle talks smoothly ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 244
															
														elif temp2== 55:
															question_lbl.set("Ques. Are you always prepared ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 255
															
														elif temp2== 66:
															question_lbl.set("Ques. Do you find it difficult to start your task ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 266
															
														elif temp2== 77:
															question_lbl.set("Ques. Do you jump into things without thinking ?")
															ans = ["A.  No", "B.  Sometimes", "C.  Most of the time", "D.  Yes"]
															count= 277
															
														elif temp2== 88:
															question_lbl.set("Ques. Do you plan your task properly before implementing ?")
															ans = ["A.  Yes", "B.  Most of the time", "C.  Sometimes", "D.  No"]
															count= 288
															
													elif temp== 3:
														if temp2== 11:
															question_lbl.set("Ques. Do you make friends easily ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 311
															
														elif temp2== 22:
															question_lbl.set("Ques. Do you talk  a lot ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 322
															
														elif temp2== 33:
															question_lbl.set("Ques. Are you skilled in handelling social situations ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 333
															
														elif temp2== 44:
															question_lbl.set("Ques. Do you feel comfortable around people ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 344
															
														elif temp2== 55:
															question_lbl.set("Ques. Do you start conversations ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 355
															
														elif temp2== 66:
															question_lbl.set("Ques. Are you hard to get to know ?")
															ans = ["A. No", "B.	Not really", "C. Kind of", "D. Yes"]
															count= 366
															
														elif temp2== 77:
															question_lbl.set("Ques. Do you warm up quickly to others ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D.	No"]
															count= 377
															
														elif temp2== 88:
															question_lbl.set("Ques. Do you like exploring new places ?")
															ans = ["A. Yes", "B. Kind of", "C. Not really", "D. No"]
															count= 388
														
													elif temp== 4:
														if temp2== 11:
															question_lbl.set("Ques. Do you show concern to others ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 411
															
														elif temp2== 22:
															question_lbl.set("Ques. Do you believe others have good intentions ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 422
															
														elif temp2== 33:
															question_lbl.set("Ques. Do you like to help the needy ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 433
															
														elif temp2== 44:
															question_lbl.set("Ques. How much charity have you done ?")
															ans = ["A.  A lot", "B.  Quite a few", "C.  Not many", "D.  No"]
															count= 444
															
														elif temp2== 55:
															question_lbl.set("Ques. Will you cheat to get ahead ?")
															ans = ["A.  Never", "B.  I dont think so", "C. Maybe", "D.  Yes"]
															count= 455
															
														elif temp2== 66:
															question_lbl.set("Ques. Do you like to boast about your virtues ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 466
															
														elif temp2== 77:
															question_lbl.set("Ques. Do you trust what people say?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 477
															
														elif temp2== 88:
															question_lbl.set("Ques. Do you believe in taking revenge ?")
															ans = ["A.  No", "A.  Not Really", "C.  Yes", "D.  Very Much"]
															count= 488
															
													elif temp== 5:
														if temp2== 11:
															question_lbl.set("Ques. Do you panic easily?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 511
															
														elif temp2== 22:
															question_lbl.set("Ques. Do you rarely get irritated ?")
															ans = ["A.  I get irritated", "B.  I get irritated sometimes", "C.  I dont get irritated much", "D.  I dont get irritated"]
															count= 522
															
														elif temp2== 33:
															question_lbl.set("Ques. Are you easily bothered by things ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 533
															
														elif temp2== 44:
															question_lbl.set("Ques. Are you easily frustrated ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 544
															
														elif temp2== 55:
															question_lbl.set("Ques. Do you have frequent mood swings ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 555
															
														elif temp2== 66:
															question_lbl.set("Ques. Do you lose your composure easily ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 566
															
														elif temp2== 77:
															question_lbl.set("Ques. Are you filled with doubts all the time ?")
															ans = ["A.  Very Much", "B.  Yes", "C.  Not Really", "D.  No"]
															count= 577
															
														elif temp2== 88:
															question_lbl.set("Ques. Are you relaxed most of the times ?")
															ans = ["A.  No", "B.  Very rarely", "C.  Not Always", "D.  Always "]
															count= 588
															
													c1.set(ans[0])
													c2.set(ans[1])
													c3.set(ans[2])
													c4.set(ans[3])
													
													def answer():
														var3= c.get()
														global o_score
														global c_score
														global e_score
														global a_score
														global n_score
														if var== 1:
															o_score= o_score+ float(var3)
														if var== 2:
															c_score= c_score+ float(var3)
														if var== 3:
															e_score= e_score+ float(var3)
														if var== 4:
															a_score= a_score+ float(var3)
														if var== 5:
															n_score= n_score+ float(var3)
													
													c= DoubleVar()
													ch1= Radiobutton(f3, textvariable= c1, variable= c, value= 1.0)
													ch2= Radiobutton(f3, textvariable= c2, variable= c, value= 0.75)
													ch3= Radiobutton(f3, textvariable= c3, variable= c, value= 0.5)
													ch4= Radiobutton(f3, textvariable= c4, variable= c, value= 0.25)
													question.place(x= 100, y= 50 )
													ch1.place(x= 100, y= 200 )
													ch2.place(x= 600, y= 200 )
													ch3.place(x= 100, y= 300 )
													ch4.place(x= 600, y= 300 )	
													
													subb= Button(f3, text= "Submit", command= answer)
													subb.place(x= 200,y= 400)
													def result():
														messagebox.showwarning(None, "Are you sure you want to end the quiz ?")
														global o_score
														global c_score
														global e_score
														global a_score
														global n_score
														#messagebox.showinfo("Score Board","Openness= "+ str(o_score)+"\n"+"Conscientiousness= "+ str(c_score)+"\n"+"Extraversion= "+ str(e_score)+"\n"+"Agreeableness= "+ str(a_score)+"\n"+"Neuroticism= "+ str(n_score))
														global scores
														#global nest
														scores[0].append(o_score)
														scores[0].append(n_score)
														scores[0].append(c_score)
														scores[0].append(a_score)
														scores[0].append(e_score)												
														#nest[0].append(scores)
														#print(scores)
                                                        
														Pfive=personality(scores)
														window5.destroy()
														import tkinter as tk
														window6 = tk.Tk()
														window6.title("Summary Analysis")
														w=window6.winfo_screenwidth()
														h=window6.winfo_screenheight()
														resolution=str(w)+'x'+str(h)
														window6.geometry(resolution)
														#window.resizable(False,False)
														OptionList = [
														"Select a question.",
														"What is the meaning of life ?",
														"What do you think about society of today ?",
														"Mobile Technology; a boon or bane. Comment.",
														"Internet the treasure of knowledge. Comment."
														] 

														variable = tk.StringVar()
														variable.set(OptionList[0])
														c= tk.StringVar()
														opt = tk.OptionMenu(window6, variable, *OptionList)
														#opt.config(width=90, font=('Helvetica', 12))
														opt.place(x= 20, y= 50)
														f1= tk.Frame(window6)
														f1.configure( height= h, width= w)
														# lbl= tk.Label(window5, textvariable=c)
														# lbl.place(x= 20, y= 100)
														labelTest = tk.Label(text="", font=('Helvetica', 12))
														labelTest.place(x= 20, y= 140)

														def callback(*args):
															labelTest.configure(text="Ques. {}".format(variable.get()))

														variable.trace("w", callback)
														txt= tk.Text(window6, height=25, width=180)
														txt.place(x= 20, y= 200)

														def sub():
															#nltk.download('punkt')#1 time download of the sentence tokenizer
															text = txt.get(1.0, tk.END)
															obj = TextBlob(text)
															global sent
															sentiment = obj.sentiment.polarity
															if sentiment == 0:
																#tk.messagebox.showinfo(None, "The text is neutral with a score of "+ str(sentiment))
																sent= "Neutral"
															elif sentiment > 0:
																#tk.messagebox.showinfo(None, "The text is positive with a score of "+ str(sentiment))
																sent= "Positive"
															else:
																#tk.messagebox.showinfo(None, "The text is negative with a score of "+ str(sentiment))
																sent= "Negative"
															window6.destroy()
															expression=interview()
															print(expression) 
															global score
															global o_score
															global c_score
															global e_score
															global a_score
															global n_score
															global ct
															dat= {"Contact Number": ct}
															upd_data= {"$set":{"Contact Number": ct,
																				"Aptitude score": score,
																				"Openness": o_score,
																				"Conscientiousness": c_score,
																				"Extraversion": e_score,
																				"Agreeableness": a_score,
																				"Neuroticism": n_score,
																				"Sentiment": sent,
																				"Personality": Pfive[0],
																				"Expression" : expression}}                                                                              
															col.update_one(dat, upd_data)


															window7 = Tk()
															window7.title("Result")
															w=window7.winfo_screenwidth()
															h=window7.winfo_screenheight()
															resolution=str(w)+'x'+str(h)
															window7.geometry(resolution)
															window7.configure(bg= "#d9d9d9")
																														
															record= col.find_one({"Contact Number": ct}) 
															#frame= Frame(window7)
															#frame.configure(bg= "white")
															res= Label(window7, text= "RESULT", font = "Times 20 bold")
															res.place(x= w/ 2, y= 20)
															nm=StringVar()
															ag=StringVar()
															ct=StringVar()
															em=StringVar()
															ed=StringVar()
															i=StringVar()
															ap=StringVar()
															o=StringVar()
															c=StringVar()
															e=StringVar()
															a=StringVar()
															n=StringVar()
															s=StringVar()
															lbl= Label(window7, text="Name :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 120)

															nam_lbl= Label(window7, textvariable=nm, height= 2, width= 50, justify= LEFT , padx= 0)
															nam_lbl.place(x= 350,y= 120)

															lbl= Label(window7, text="Age :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 170)

															age_lbl= Label(window7, textvariable=ag, height= 2, width= 50)
															age_lbl.place(x=350,y=170)

															lbl= Label(window7, text="Contact Number :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 220)

															ct_lbl= Label(window7, textvariable=ct, height= 2, width= 50)
															ct_lbl.place(x=350,y=220)

															lbl= Label(window7, text="Email- ID :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 270)

															email_lbl= Label(window7, textvariable=em, height= 2, width= 50)
															email_lbl.place(x=350,y=270)

															lbl= Label(window7, text="Education Details :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 320)

															edu_lbl= Label(window7, textvariable=ed, height= 2, width= 50)
															edu_lbl.place(x=350,y=320)

															img_lbl= Label(window7, textvariable=i, height= 20, width= 40)
															img_lbl.place(x= w- 350,y= 120)

															lbl= Label(window7, text="Aptitude Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 370)

															apt_lbl= Label(window7, textvariable=ap, height= 2, width= 50)
															apt_lbl.place(x=350,y=370)

															lbl= Label(window7, text="Openness Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 420)

															o_lbl= Label(window7, textvariable=o, height= 2, width= 50)
															o_lbl.place(x=350,y=420)

															lbl= Label(window7, text="Conscientiousness Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 470)

															c_lbl= Label(window7, textvariable=c, height= 2, width= 50)
															c_lbl.place(x=350,y=470)

															lbl= Label(window7, text="Extraversion Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 520)

															e_lbl= Label(window7, textvariable=e, height= 2, width= 50)
															e_lbl.place(x=350,y=520)

															lbl= Label(window7, text="Agreeableness Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 570)

															a_lbl= Label(window7, textvariable=a, height= 2, width= 50)
															a_lbl.place(x=350,y=570)

															lbl= Label(window7, text="Neuroticism Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 620)

															n_lbl= Label(window7, textvariable=n, height= 2, width= 50)
															n_lbl.place(x=350,y=620)

															lbl= Label(window7, text="Summary Score :", height= 2, width= 40, justify= "left")
															lbl.place(x= 50, y= 670)

															sent_lbl= Label(window7, textvariable=s, height= 2, width= 50)
															sent_lbl.place(x=350,y=670)			
															nm.set(record["Name"])
															ag.set(record["Age"])
															ct.set(record["Contact Number"])
															ed.set(record["Grad"])
															em.set(record["Email-ID"])
															ap.set(str(record["Aptitude score"]))
															o.set(str(record["Openness"]))
															c.set(str(record["Conscientiousness"]))
															e.set(str(record["Extraversion"]))
															a.set(str(record["Agreeableness"]))
															n.set(str(record["Neuroticism"]))
															s.set(record["Sentiment"])
															def exit():
																messagebox.showinfo("Exit", "Thank you for taking our test. All the best for your selection !")
																window7.destroy()
															exit_btn= Button(window7, text= "Exit", command= exit)
															exit_btn.place(x= w/ 2, y= 740)
															window7.mainloop()													
															
															
															

														btn1= tk.Button(window6, text= "Submit", command= sub)
														btn1.place(x= w/2 - 100, y= 700)

														def clr():
															variable.set(OptionList[0])
															labelTest.configure(text="")
															txt.delete(1.0, tk.END)
															
														btn2= tk.Button(window6, text= "Clear", command= clr)
														btn2.place(x= w/2 + 100,y= 700)

														window6.configure()
														window6.mainloop()
														
													ress= Button(f3, text= "End Quiz", command= result)
													ress.place(x= 500,y= 400)
													
												qs= IntVar()
												q1= Radiobutton(f2, text= "Ques 1.", variable= qs, command= mcq, value= 11)
												q1.place(x= 70, y= 20)
												q2= Radiobutton(f2, text= "Ques 2.", variable= qs, command= mcq, value= 22)
												q2.place(x= 70, y= 100)
												q3= Radiobutton(f2, text= "Ques 3.", variable= qs, command= mcq, value= 33)
												q3.place(x= 70, y= 180)
												q4= Radiobutton(f2, text= "Ques 4.", variable= qs, command= mcq, value= 44)
												q4.place(x= 70, y= 260)
												q5= Radiobutton(f2, text= "Ques 5.", variable= qs, command= mcq, value= 55)
												q5.place(x= 70, y= 340)
												q6= Radiobutton(f2, text= "Ques 6.", variable= qs, command= mcq, value= 66)
												q6.place(x= 70, y= 420)
												q7= Radiobutton(f2, text= "Ques 7.", variable= qs, command= mcq, value= 77)
												q7.place(x= 70, y= 500)
												q8= Radiobutton(f2, text= "Ques 8.", variable= qs, command= mcq, value= 88)
												q8.place(x= 70, y= 580)

										opn= IntVar()
										op1= Radiobutton(f1, text= "Openness", variable= opn, command= quest, value= 1)
										op1.place(x= 50, y= 30)
										op2= Radiobutton(f1, text= "Conscientiousness", variable= opn, command= quest, value= 2)
										op2.place(x= 300, y= 30)
										op3= Radiobutton(f1, text= "Extraversion", variable= opn, command= quest, value= 3)
										op3.place(x= 550, y= 30)
										op1= Radiobutton(f1, text= "Agreeableness", variable= opn, command= quest, value= 4)
										op1.place(x= 800, y= 30)
										op1= Radiobutton(f1, text= "Neuroticism", variable= opn, command= quest, value= 5)
										op1.place(x= 1050, y= 30)
										lbl= Label(f1, text= "Time Left :")
										lbl.place(x= 1250, y= 30)
										tm2= Entry(f1)
										tm2.place(x= 1350, y= 30)

										threading.Thread(target=time_lft).start()
										window5.mainloop()
										
									subb= Button(f3, text= "End Quiz", command= re)
									subb.place(x= 500,y= 500)
									
								q= IntVar()
								q1= Radiobutton(f2, text= "Ques 1.", variable= q, command= mcq, value= 11)
								q1.place(x= 70, y= 50)
								q2= Radiobutton(f2, text= "Ques 2.", variable= q, command= mcq, value= 22)
								q2.place(x= 70, y= 150)
								q3= Radiobutton(f2, text= "Ques 3.", variable= q, command= mcq, value= 33)
								q3.place(x= 70, y= 250)
								q4= Radiobutton(f2, text= "Ques 4.", variable= q, command= mcq, value= 44)
								q4.place(x= 70, y= 350)
								q5= Radiobutton(f2, text= "Ques 5.", variable= q, command= mcq, value= 55)
								q5.place(x= 70, y= 450)	

						op= IntVar()
						op1= Radiobutton(f1, text= "Quantitative Reasoning", variable= op, command= quest, value= 1)
						op1.place(x= 50, y= 30)
						op2= Radiobutton(f1, text= "Verbal Reasoning", variable= op, command= quest, value= 2)
						op2.place(x= 450, y= 30)
						op3= Radiobutton(f1, text= "Logical Reasoning", variable= op, command= quest, value= 3)
						op3.place(x= 850, y= 30)
						lbl= Label(f1, text= "Time Left :")
						lbl.place(x= 1250, y= 30)
						tm= Entry(f1)
						tm.place(x= 1350, y= 30)

						threading.Thread(target=time_lft).start()
						window4.mainloop()
						window3.Show(False)
				sub= wx.Button(box2, label= "Submit", size= (150, 25), pos= (width/ 2-120, height/2- 120))
				sub.Bind(wx.EVT_BUTTON, f)
				window3.Show(True) 
				window2.Show(False)
			else:
				wx.MessageBox('Login Failed.\nIncorrect Username or Password')
	sub= wx.Button(box1, size= (150,25), pos= (50, 370), label= "Login")
	sub.Bind(wx.EVT_BUTTON, onlogin)
	def onclr(self):
		email1.SetValue("")
		pd.SetValue("")
	clr= wx.Button(box1, size= (150,25), pos= (250, 370), label= "Clear")
	clr.Bind(wx.EVT_BUTTON, onclr)
	font = wx.Font(24, wx.ROMAN, wx.NORMAL, wx.BOLD)
	label.SetFont(font)

	window2.Show(True) 
	window.Show(False)
sub= wx.Button(panel, size= (150,25), pos= (width/2- 500, height-150), label= "Submit") 
sub.Bind(wx.EVT_BUTTON, onsub)
def onclr(self):
	name.SetValue("")
	age.SetValue("")
	contact.SetValue("")
	email.SetValue("")
	other.SetValue("")
	qua1.SetValue("")
	qua2.SetValue("")
	qua3.SetValue("")
	inst1.SetValue("")
	inst2.SetValue("")
	inst3.SetValue("")
	brd1.SetValue("")
	brd2.SetValue("")
	brd3.SetValue("")
	gp1.SetValue("")
	gp2.SetValue("")
	gp3.SetValue("")
	cs.SetValue("")
	m.SetValue(False)
	f.SetValue(False)
	ot.SetValue(False)
	ind.SetValue(False)
	othr.SetValue(False)
	other.SetHint("Enter here")
	other.Enable(False)
clr= wx.Button(panel, size= (150,25), pos= (width/2+ 400, height-150), label= "Clear") 
clr.Bind(wx.EVT_BUTTON, onclr)

window.Show(True) 
app.MainLoop()		
restartkernel()
# Out:
# Using TensorFlow backend.
# C:\Users\91996\Anaconda3\envs\pratik\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\91996\Anaconda3\envs\pratik\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\91996\Anaconda3\envs\pratik\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
