# %%
from tkinter import *
from tkinter import messagebox
from tkinter import ttk
import wx
import pymongo
#from ocean_upd import *

client = pymongo.MongoClient("mongodb+srv://Vaibhav:test@cluster0-4wlro.mongodb.net/test?retryWrites=true&w=majority")
db = client.OCEAN
col = db.user
count= 0
chky= [None]* 100
chkn= [None]* 100
ys= [None]* 100
no= [None]* 100
rec= [None]* 100
app= wx.App() 
width, height = wx.GetDisplaySize()
#resolution=str(w)+'x'+str(h)
#app.geometry(resolution)
window= wx.Frame(None, title = "Admin Login", size = (500, 530), pos= (width/4,height/4)) 
panel= wx.Panel(window) 
box1= wx.StaticBox(panel, wx.ID_ANY, "", size =(450, 450), pos= (15, 15))
label= wx.StaticText(box1, label="Administrator Login", pos= (80, 50))
box= wx.StaticBox(box1, wx.ID_ANY, "Username", size =(400, 80), pos= (25, 150))
usn= wx.TextCtrl(box1, size= (365, 25), pos= (40, 180))
box= wx.StaticBox(box1, wx.ID_ANY, "Password", size =(400, 80), pos= (25, 250))
pd= wx.TextCtrl(box1, size= (365, 25), pos= (40, 280), style= wx.TE_PASSWORD)
def onlogin(self):
    u= usn.GetValue()
    pwd= pd.GetValue()
    if u== "" or pwd== "" or (u.lower()!= "vaibhav" and pwd!= "ocean") :
        wx.MessageBox("Access Denied ! Try Again.")
    else:
        wx.MessageBox("Login Successful. Welcome "+u.title())
        window.Show(0)
        reslt= Tk()
        reslt.title("Result Analysis")
        w=reslt.winfo_screenwidth()
        h=reslt.winfo_screenheight()
        resolution=str(w)+'x'+str(h)
        reslt.geometry(resolution)
        reslt.configure()
        lbl= Label(reslt, text= "Candidate Response Sheet", font=('Helvetica', 20))
        lbl.place(x= w/2- 150, y= 20)
        lbl= Label(reslt, text= "Select corresponding\ncandidate ?")
        lbl.place(x= w-80, y= 110, anchor= CENTER)
        lbl= Label(reslt, text= "No")
        lbl.place(x= w-50, y= 135)
        lbl= Label(reslt, text= "Yes")
        lbl.place(x= w-120, y= 135)
        disp= Text(reslt, height= 35, width= 170)
        disp.place(x= 10, y= 120)
        #chky= Checkbutton(reslt, variable= y)
        #chky.place(x= w-120, y= 180)
        #chkn= Checkbutton(reslt, variable= n)
        #chkn.place(x= w-50, y= 180)
        '''chky1= Checkbutton(reslt, variable= y)
        chky1.place(x= w-120, y= 220)
        chky2= Checkbutton(reslt, variable= y)
        chky2.place(x= w-50, y= 220)'''
        disp.insert(INSERT, "\nName\t\t\t\tContact Number\t\t\t\tAptitude Score\t\t\t\tPersonality\t\t\t\tExpression\t\t\t\tSentiment")
        disp.insert(END, "\n\n\n")
        
        for i in col.find({"Candidate Selected": ""}): 
            disp.insert(INSERT, i["Name"]+'\t\t\t\t'+ i["Contact Number"]+'\t\t\t\t'+ str(i["Aptitude score"])+'\t\t\t\t'+ str(i["Personality"])+'\t\t\t\t'+ str(i["Expression"])+'\t\t\t\t'+ i["Sentiment"])
           # disp.insert(INSERT, i["Name"]+'\t'+ i["Contact Number"]+'\t\t\t'+ str(i["Aptitude score"])+'\t\t\t'+str(i["Personality"])+'\t\t\t'+ str(i["Expression"]))+'\t'+ i["Sentiment"])
            disp.insert(END, '\n\n')
            #print(type(i))
            global count
            rec[count]= i
            count= count+ 1
        #print(rec)
              
        for i in range(count):
            chky[i]= ttk.Checkbutton(reslt, variable= ys[i])
            chky[i].place(x= w-120, y= 180+ i*40)
            chkn[i]= ttk.Checkbutton(reslt, variable= ys[i])
            chkn[i].place(x= w-50, y= 180+ i*40)
            
        def sub_rec():
            global rec, chky, chkn, ys, no
            rec= list(filter(None, rec))
            chky= list(filter(None, chky))
            chkn= list(filter(None, chkn))
            ys= list(filter(None, ys))
            no= list(filter(None, no))
            
            for i in range(len(rec)):
                #print(chky[i].state())
                if chky[i].instate(['selected']):
                    #print(rec[i]["Contact Number"])
                    dat= {"Contact Number": rec[i]["Contact Number"]}
                    upd_data= {"$set":{"Contact Number": rec[i]["Contact Number"],
                                        "Candidate Selected": "Yes"}}
                    col.update_one(dat, upd_data)
                
                elif chkn[i].instate(['selected']):
                    #print(rec[i])
                    dat= {"Contact Number": rec[i]["Contact Number"]}
                    upd_data= {"$set":{"Contact Number": rec[i]["Contact Number"],
                                        "Candidate Selected": "No"}}
                    col.update_one(dat, upd_data)
        
        
        
        submit=Button(reslt, text= "Submit", command= sub_rec)
        submit.place(x= w/2 -50, y= h- 150)
        
        
        reslt.mainloop()
sub= wx.Button(box1, size= (150,25), pos= (50, 370), label= "Login")
sub.Bind(wx.EVT_BUTTON, onlogin)
def onclr(self):
	usn.SetValue("")
	pd.SetValue("")
clr= wx.Button(box1, size= (150,25), pos= (250, 370), label= "Clear")
clr.Bind(wx.EVT_BUTTON, onclr)
font = wx.Font(24, wx.ROMAN, wx.NORMAL, wx.BOLD)
label.SetFont(font)

window.Show(1)
app.MainLoop()
